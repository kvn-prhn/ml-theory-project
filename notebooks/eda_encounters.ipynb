# %%
import pandas as pd
import numpy as np
import pathlib

from encounters_columns import EncountersColumns

# %%
proc_dir = pathlib.Path('./proc_data_old/')
assert proc_dir.exists() and len(list(proc_dir.glob('*.parquet'))) > 0

# %%
enc_d = pd.read_parquet(proc_dir / 'encounters.parquet')
enc_d
# Out:
#         Event Date                       Responsible AOR  \
# 0       2023-09-26        Chicago Area of Responsibility
# 1       2023-10-31        Chicago Area of Responsibility
# 2       2024-07-05          Miami Area of Responsibility
# 3       2024-07-12  New York City Area of Responsibility
# 4       2024-07-29  New York City Area of Responsibility
# ...            ...                                   ...
# 1286186 2025-01-09      Baltimore Area of Responsibility
# 1286187 2025-05-10             HQ Area of Responsibility
# 1286188 2025-03-20  San Francisco Area of Responsibility
# 1286189 2025-01-06       St. Paul Area of Responsibility
# 1286190 2025-03-24       St. Paul Area of Responsibility
#
#                                           Responsible Site  \
# 0                       CHICAGO, IL, DOCKET CONTROL OFFICE
# 1                       CHICAGO, IL, DOCKET CONTROL OFFICE
# 2                          Collier County Sheriff's Office
# ...

# %%
enc_d[EncountersColumns.EVENT_TYPE].value_counts()
# Out:
# Event Type
# CAP Local                                                     793513
# ERO Criminal Alien Program                                    131951
# Non-Detained Docket Control                                    64824
# Fugitive Operations (Event)                                    63428
# Administrative Non-Criminal Individual                         28798
# CAP Federal                                                    21630
# 287(g) Program Activities                                      19691
# Alternatives to Detention                                      16771
# ERO Reprocessed                                                15922
# CAP State                                                      11785
# Administrative Criminal Alien                                  10995
# Fugitive Operations (Lead)                                      6860
# ERO Criminal Prosecutions                                       3933
# ...
