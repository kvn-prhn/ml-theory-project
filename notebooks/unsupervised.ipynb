# %%
import os
os.chdir("/home/wes/projects/ml_project_final/ml-theory-project")
import pathlib
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.cluster import DBSCAN

# %%
df_initial = pd.read_parquet('/home/wes/projects/ml_project_final/ml-theory-project/ice_data/clean_data/merged_data.parquet')

# %%
df_copy = df_initial.copy(deep=True)
df_copy = df_copy.groupby("Unique Identifier").first()

# %%
df_test = df_copy.copy(deep=True)
df_test.drop_duplicates(inplace=True)
df_test['Birth Year'] = df_test['Birth Year'].astype('Int64')
df_test['Age'] = 2025 - df_test['Birth Year'] 

bins = [0, 24, 34, 44, 54, 200]
labels = ['<18-24', '25-34', '35-44', '45-54', '55+']
df_test['AgeBand'] = pd.cut(df_test['Age'], bins=bins, labels=labels, right=True)
features_num = []
features_cat = ['AgeBand', 'Gender', 'Detention Facility', 'Citizenship Country', 'Event Month']

sc = StandardScaler()

df_test['Deported'] = df_test['Deported'].map({True: 1, False: 0})

df_test = df_test[df_test['Gender'] != 'Unknown']
df_test['Detention Facility'] = df_test['Detention Facility'].apply(lambda x: x.lower() if x else x)
df_test['Final Program'] = df_test['Final Program'].apply(lambda x: x.lower() if x else x)
df_test['Citizenship Country'] = df_test['Citizenship Country'].apply(lambda x: x.lower() if x else x)

df_test['Event Year'] = df_test['Event Date'].dt.year
df_test = df_test[df_test['Event Year'] > 2024]
cols_for_model = features_cat + ['Deported']
db_df = df_test[cols_for_model].dropna()

X_db = db_df[features_cat]

db_pre = ColumnTransformer(
    transformers=[
        ('categorical_features', OneHotEncoder(handle_unknown='ignore'), features_cat),
    ],
    remainder='drop'
)

X_db_proc = db_pre.fit_transform(X_db)
db = DBSCAN(eps=0.2, min_samples=35, n_jobs=-1)
db_labels = db.fit_predict(X_db_proc)
db_df['cluster_dbscan'] = db_labels
cluster_risks = db_df.groupby('cluster_dbscan')['Deported'].mean()
cluster_sizes = db_df['cluster_dbscan'].value_counts().sort_index()
num_profile = pd.DataFrame(index=cluster_risks.index)
cat_profile = db_df.groupby('cluster_dbscan')[features_cat].agg(
    lambda x: x.value_counts().index[0]
)

cluster_profile = pd.concat(
    [num_profile, cat_profile, cluster_risks.rename('deportation_rate')],
    axis=1
)
cluster_profile = cluster_profile.join(cluster_sizes.rename('Cluster Sizes'))

cluster_profile = cluster_profile.sort_values(
    ['Cluster Sizes', 'deportation_rate'],
    ascending=[False, False]
)

cluster_profile
# Out:
#                AgeBand  Gender         Detention Facility Citizenship Country  \
# cluster_dbscan
# -1               25-34    Male  montgomery processing ctr              mexico
#  112             25-34    Male  florence staging facility              mexico
#  66              35-44    Male  montgomery processing ctr              mexico
#  59              35-44    Male  montgomery processing ctr              mexico
#  89              25-34    Male       bluebonnet det fclty              mexico
# ...                ...     ...                        ...                 ...
#  43              35-44    Male        harlingen hold room              mexico
#  22              25-34    Male        harlingen hold room              mexico
#  181             35-44  Female              los cust case              mexico
#  79              25-34    Male         montgomery hold rm              mexico
#  68              25-34    Male  miami (miramar) hold room                cuba
#
# ...

# %%
X_db.shape[0] - 98141
# Out:
# 10061

# %%
cluster_profile[cluster_profile['Gender'] == 'Female']
# Out:
#                AgeBand  Gender Detention Facility Citizenship Country  \
# cluster_dbscan
# 181              35-44  Female      los cust case              mexico
#
#                Event Month  deportation_rate  Cluster Sizes
# cluster_dbscan
# 181                   July          0.371429             35

# %%
cluster_profile.sort_values('deportation_rate', ascending=False).reset_index(drop = True)
# Out:
#     AgeBand Gender           Detention Facility Citizenship Country  \
# 0     35-44   Male         bluebonnet det fclty              mexico
# 1     35-44   Male  alexandria staging facility           guatemala
# 2     35-44   Male         bluebonnet det fclty              mexico
# 3     25-34   Male  alexandria staging facility           guatemala
# 4     25-34   Male  alexandria staging facility           guatemala
# ..      ...    ...                          ...                 ...
# 191   25-34   Male        atlanta dist. hold rm              mexico
# 192   35-44   Male        atlanta dist. hold rm              mexico
# 193   35-44   Male                nyc hold room             ecuador
# 194   25-34   Male             dallas f.o. hold           venezuela
# 195   25-34   Male    miami (miramar) hold room                cuba
#
#     Event Month  deportation_rate  Cluster Sizes
# 0          June          0.950000             60
# 1          June          0.945946             37
# ...

# %%
cluster_profile.sort_values('deportation_rate', ascending=True).head(10).reset_index(drop = True).to_csv('less_cluster.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

db_df['Deported'] = db_df['Deported'].astype(float)

cluster_risks = db_df.groupby('cluster_dbscan')['Deported'].mean()
cluster_sizes = db_df['cluster_dbscan'].value_counts().sort_index()

summary = pd.DataFrame({
    'cluster': cluster_risks.index,
    'deportation_rate': cluster_risks.values,
    'cluster_size': cluster_sizes.values
})

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
db_df['Deported'].mean()
# Out:
# np.float64(0.4240034209150948)

# %%
# Exclude noise
cp = cluster_profile.copy()
cp = cp[cp.index != -1]

overall_rate = db_df['Deported'].mean()

plt.figure(figsize=(8, 5))
sns.histplot(cp['deportation_rate'], bins=20, kde=False)
plt.axvline(overall_rate, linestyle='--', label=f'Overall rate: {overall_rate:.2f}')
plt.xlabel('Cluster-level deportation rate')
plt.ylabel('Number of clusters')
plt.title('Distribution of Deportation Risk Across DBSCAN Clusters')
plt.legend()
plt.tight_layout()
plt.show()

# %%
fac_stats = (
    db_df
    .groupby('Detention Facility')
    .agg(
        deportation_rate=('Deported', 'mean'),
        n=('Deported', 'size')
    )
)
fac_top = fac_stats[fac_stats['n'] >= 1000]
fac_top = fac_top.sort_values('deportation_rate', ascending=False).head(15)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=fac_top.reset_index(),
    y='Detention Facility',
    x='deportation_rate'
)
plt.xlabel('Average deportation rate')
plt.ylabel('Detention facility')
plt.title('Average Deportation Rate by Detention Facility (Top by Volume)')
plt.tight_layout()
plt.show()

# %%
country_stats = (
    db_df
    .groupby('Citizenship Country')
    .agg(
        deportation_rate=('Deported', 'mean'),
        n=('Deported', 'size')
    )
)

country_top = country_stats[country_stats['n'] >= 1000]
country_top = country_top.sort_values('deportation_rate', ascending=False).head(15)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=country_top.reset_index(),
    y='Citizenship Country',
    x='deportation_rate'
)
plt.xlabel('Average deportation rate')
plt.ylabel('Citizenship country')
plt.title('Average Deportation Rate by Citizenship Country (Top by Volume)')
plt.tight_layout()
plt.show()

# %%
month_order = [
    'January', 'February', 'March', 'April', 'May', 'June',
    'July'
]
month_stats = (
    db_df
    .groupby('Event Month')
    .agg(
        deportation_rate=('Deported', 'mean'),
        n=('Deported', 'size'),
        deported=('Deported', 'sum')
    )
    .reset_index()
)
month_stats['Event Month'] = pd.Categorical(
    month_stats['Event Month'],
    categories=month_order,
    ordered=True
)
# Out:
# /tmp/ipykernel_2593819/2336167580.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('Event Month')

# %%
plt.figure(figsize=(10, 6))
plt.plot(
    month_stats['Event Month'],
    month_stats['deportation_rate'],
    marker='o'
)
plt.xticks(rotation=45)
plt.xlabel('Event month')
plt.ylabel('Average Deportation Rate')
plt.title('Deportation Rates by Month')
ax1 = plt.gca()
ax2 = ax1.twinx()
ax2.bar(
    month_stats['Event Month'],
    month_stats['n'],
    alpha=0.2
)
ax2.set_ylabel('Number of cases (n)')
plt.tight_layout()
plt.show()

# %%
162101 - 98141 = 63960
# Out:
# 63960
